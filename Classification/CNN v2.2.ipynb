# %%
import tensorflow as tf
import numpy as np

# %%
# X_train, Y_train = load_cifar_10_data_batch(path + '/cifar-10-batches-py/data_batch_1')
# X_test, Y_test = load_cifar_10_data_batch

# %%
with np.load('Buildingtop.npz') as Buildingtop:
    train_x = Buildingtop['train_x']
    train_y = Buildingtop['train_Y']
    test_x = Buildingtop['test_x']
    test_y = Buildingtop['test_y']
with np.load('Treetop.npz') as Treetop:
    train_x = np.vstack((train_x,Treetop['train_x']))
    train_y = np.hstack((train_y,Treetop['train_Y']))
    test_x = np.vstack((test_x,Treetop['test_x']))
    test_y = np.hstack((test_y,Treetop['test_y']))
with np.load('BigBuilding.npz') as BigBuilding:
    train_x = np.vstack((train_x,BigBuilding['train_x']))
    train_y = np.hstack((train_y,BigBuilding['train_Y']))
    test_x = np.vstack((test_x,BigBuilding['test_x']))
    test_y = np.hstack((test_y,BigBuilding['test_y']))
with np.load('skycloudcontrast.npz') as skycloudcontrast:
    train_x = np.vstack((train_x,skycloudcontrast['train_x']))
    train_y = np.hstack((train_y,skycloudcontrast['train_Y']))
    test_x = np.vstack((test_x,skycloudcontrast['test_x']))
    test_y = np.hstack((test_y,skycloudcontrast['test_y']))

# %%
print(np.shape(train_x))
print(np.shape(train_y))
print(np.shape(test_x))
print(np.shape(test_y))

# train_y=train_y.reshape(200,1)
# test_y=test_y.reshape(20,1)
num_example=train_x.shape[0]
arr=np.arange(num_example)
np.random.shuffle(arr)
train_x=train_x[arr]
train_y=train_y[arr]
# train_y=train_y.reshape(200,)
# test_y=test_y.reshape(20,)
print(np.shape(train_x))
print(np.shape(train_y))
# Out:
# (400, 129792)
# (400,)
# (80, 129792)
# (80,)
# (400, 129792)
# (400,)

# %%
X_train=train_x
Y_train=train_y
X_test=test_x
Y_test=test_y

# %%
print(train_y)
# Out:
# [2 1 2 3 3 3 0 1 0 3 0 3 1 1 3 2 3 1 2 0 3 0 1 2 0 1 3 2 3 3 3 2 1 1 3 0 3
#  3 0 3 2 1 2 0 3 0 1 1 2 2 2 2 1 0 1 1 1 2 0 3 0 3 3 1 0 0 0 0 0 3 0 3 2 2
#  3 1 2 2 1 3 1 0 2 1 1 2 0 3 3 3 2 2 2 0 0 1 1 2 0 1 1 1 1 3 1 0 1 2 1 2 0
#  1 1 3 3 3 3 3 1 3 0 3 3 1 2 2 1 0 0 2 3 0 3 1 1 0 1 3 1 1 1 1 2 0 2 3 3 3
#  2 3 3 1 3 2 3 0 3 1 2 2 2 0 2 3 1 3 2 2 3 1 2 0 1 0 2 1 0 3 3 0 2 0 1 3 2
#  3 1 3 2 3 0 0 0 1 2 1 2 2 2 3 3 2 3 2 0 0 3 0 1 3 0 1 3 0 0 2 3 1 0 2 0 0
#  2 2 1 1 0 0 3 0 0 1 1 3 1 0 2 2 1 2 0 3 0 0 2 1 0 1 2 3 2 1 3 0 2 1 0 0 3
#  3 2 1 1 0 0 3 0 1 1 1 1 3 3 0 2 0 2 0 0 3 2 1 1 3 1 0 0 1 3 0 2 1 3 2 2 2
#  1 3 0 0 3 0 2 0 3 0 1 1 3 2 0 0 1 2 1 3 2 2 2 1 0 2 1 2 2 2 2 0 0 2 2 1 1
#  2 3 1 0 1 3 2 2 3 1 2 2 1 0 0 1 0 2 1 2 0 3 3 2 0 2 2 0 0 1 3 1 3 3 3 3 3
#  2 1 0 2 0 0 0 2 0 2 1 1 0 2 2 0 3 3 1 0 1 0 3 2 3 3 1 2 3 3]

# %%
# 2.function
# 2.1 # init weight random distribution
def weights(shape):
    return tf.Variable(tf.random_normal(shape=shape, mean=0, stddev=0.1))
# 2.2 init bias
def biases(shape):
    return tf.Variable(tf.constant(0.1, shape=shape))

# 2.3 #     
# x input tensor of shape [batch, in_height, in_width, in_channels]
# W filter/kernel tensor of shape [filter_height, filter_width, in_channels, out_channels]
# strides[0]=strides[3]=1 strides[x] stands "x"direction, strides[y]stands "y" dicrection
# padding: "SAME",OR "VALID"
def conv2d(x, W):
    return tf.nn.conv2d(input=x, filter=W, strides=[1,1,1,1], padding='SAME', use_cudnn_on_gpu=True)
# 2.4 pooling layer
def max_pool(x):
    return tf.nn.max_pool(value=x, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')


# compute accuracy
def compute_accuracy(x_test, y_test):
    global predict_function
    predict_test = sess.run(predict_function, feed_dict={xs:x_test})
    # 比较预测值与测试集最大值下标是否相同, 返回相同个数
    """
    =================================
    """
    y_test_one_hot = tf.one_hot(y_test, depth = 4)
    correct_num = tf.equal(tf.argmax(predict_test, 1), tf.argmax(y_test_one_hot, 1))
    # calculate mean then turn to float32
    accuracy = tf.reduce_mean(tf.cast(correct_num, tf.float32))
    return sess.run(accuracy, feed_dict={xs:x_test, ys:y_test})

# %%
"""
=================
"""
# 3.define inpute shape
xs = tf.placeholder(tf.float32, [None, 416*104*3])/255
ys = tf.placeholder(tf.int32, [None])

# 4. build process
# # change xs format into a 4D vector [batch, in_height, in_width, in_channels]
x0 = tf.transpose(tf.reshape(xs, [-1, 3, 104, 416]), perm=[0, 2, 3, 1])

# 4.1 conv1→pooling→conv2→pooling

# after first pooling image is 208x52
# after second pooling image is 104x26
# activation function use relu (alternative)
# conv1 layer uses 30 conv2 uses 60 (alternative)
W_conv1 = weights([5, 5, 3, 30])
b_conv1 = biases([30])
a_conv1 = conv2d(x0, W_conv1) + b_conv1
z_conv1 = tf.nn.relu(a_conv1)
h_conv1 = max_pool(z_conv1)

W_conv2 = weights([5, 5, 30, 60])
b_conv2 = biases([60])
a_conv2 = conv2d(h_conv1, W_conv2) + b_conv2
z_conv2 = tf.nn.relu(a_conv2)
h_conv2 = max_pool(z_conv2)

# output 104*26*60

"""
==============
"""
x_conv0 = tf.reshape(h_conv2, [-1, 104*26*60])
# 4.2 fully connected networks
"""
=============
"""
W_fc1 = weights([104*26*60, 1024])
b_fc1 = biases([1024])
a_fc1 = tf.matmul(x_conv0, W_fc1) + b_fc1
z_fc1 = tf.nn.sigmoid(a_fc1)
"""
==========================drop out

"""
# drop_prob = tf.placeholder(tf.float32)
# h_fc1_drop = tf.nn.dropout(z_fc1,drop_prob)

"""
===============
"""
W_fc2 = weights([1024, 4])
b_fc2 = biases([4])
a_fc2 = tf.matmul(z_fc1, W_fc2) + b_fc2
# z_fc2 = tf.nn.sigmoid(a_fc2)


# 4.3 prediction function
predict_function = a_fc2
"""
=============================
"""
ys_one_hot = tf.one_hot(ys, depth = 4)
# cost_function = tf.reduce_mean(-tf.reduce_sum(ys*tf.log(predict_function), reduction_indices=[1]))
cost_function = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=ys_one_hot, logits=predict_function))

# 4.4 Optimizer uses GradientDescentOptimizer
#  which minimise the cost_function
train_step = tf.train.GradientDescentOptimizer(0.01).minimize(cost_function)
# train_step = tf.train.AdamOptimizer(0.01).minimize(cost_function)

# %%
# 5. 训练并图像化表示
sess = tf.Session()
sess.run(tf.global_variables_initializer())

saver = tf.train.Saver()

for epoch in range(20):
    for t in range(0, 400-10, 10):
        iter = t // 10
        xs_batch, ys_batch = X_train[t:t+10], Y_train[t:t+10]
        sess.run(train_step, feed_dict={xs:xs_batch, ys:ys_batch})
        if iter % 10== 0:
            cost = sess.run(cost_function, feed_dict={xs: xs_batch, ys: ys_batch})
            accuracy = compute_accuracy(X_test, Y_test)
            print("epoch:%s,iters:%s, cost:%s, accuracy:%s" % (epoch+1, iter, cost, accuracy))
            print("Building top: ", compute_accuracy(X_test[0:20], Y_test[0:20]))
            print("tree top: ", compute_accuracy(X_test[20:40], Y_test[20:40]))
            print("big building: ", compute_accuracy(X_test[40:60], Y_test[40:60]))
            print("contrast: ", compute_accuracy(X_test[60:80], Y_test[60:80]))
# saver.save(sess, '/Users/wanglei/Downloads/test/model.ckpt')


"""
============================
"""
# for i in range(20):
#     xs_batch, ys_batch = X_train, Y_train
#     sess.run(train_step, feed_dict={xs:xs_batch, ys:ys_batch})
#     cost = sess.run(cost_function, feed_dict={xs: xs_batch, ys: ys_batch})
#     accuracy = compute_accuracy(X_test, Y_test)
#     print("iters:%s, cost:%s, accuracy:%s" % (i, cost, accuracy))

sess.close()
# Out:
# WARNING:tensorflow:From <ipython-input-7-109313d5f81e>:86: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# epoch:0,iters:0, cost:2.3184898, accuracy:0.25
# Building top:  0.05
# tree top:  0.85
# big building:  0.1
# contrast:  0.0
# epoch:0,iters:10, cost:1.4803114, accuracy:0.275
# Building top:  0.2
# tree top:  0.0
# big building:  0.9
# contrast:  0.0
# epoch:0,iters:20, cost:1.3880672, accuracy:0.2875
# Building top:  0.4
# tree top:  0.25
# big building:  0.2
# contrast:  0.3
# epoch:0,iters:30, cost:1.2874534, accuracy:0.375
# Building top:  0.8
# tree top:  0.3
# big building:  0.15
# contrast:  0.25
# epoch:1,iters:0, cost:1.6218002, accuracy:0.475
# Building top:  0.85
# tree top:  0.55
# big building:  0.3
# contrast:  0.2
# epoch:1,iters:10, cost:0.9982503, accuracy:0.4875
# Building top:  0.9
# tree top:  0.05
# big building:  1.0
# contrast:  0.0
# epoch:1,iters:20, cost:0.55234396, accuracy:0.675
# Building top:  0.85
# tree top:  0.85
# big building:  0.3
# contrast:  0.7
# epoch:1,iters:30, cost:0.66400695, accuracy:0.7375
# Building top:  0.9
# tree top:  0.75
# big building:  0.55
# contrast:  0.75
# epoch:2,iters:0, cost:0.8355297, accuracy:0.7125
# Building top:  0.9
# tree top:  0.9
# big building:  0.5
# contrast:  0.55
# epoch:2,iters:10, cost:0.67027843, accuracy:0.5125
# Building top:  0.85
# tree top:  0.15
# big building:  1.0
# contrast:  0.05
# epoch:2,iters:20, cost:0.37088484, accuracy:0.775
# Building top:  0.9
# tree top:  0.9
# big building:  0.5
# contrast:  0.8
# epoch:2,iters:30, cost:0.88305056, accuracy:0.6625
# Building top:  0.75
# tree top:  0.85
# big building:  0.45
# contrast:  0.6
# epoch:3,iters:0, cost:0.69074744, accuracy:0.7125
# Building top:  0.8
# tree top:  0.9
# big building:  0.55
# contrast:  0.6
# epoch:3,iters:10, cost:0.8745872, accuracy:0.5375
# Building top:  0.85
# tree top:  0.3
# big building:  0.95
# contrast:  0.05
# epoch:3,iters:20, cost:0.6055988, accuracy:0.725
# Building top:  0.75
# tree top:  0.95
# big building:  0.35
# contrast:  0.85
# epoch:3,iters:30, cost:0.5993773, accuracy:0.6625
# Building top:  0.75
# tree top:  0.8
# big building:  0.35
# contrast:  0.75
# epoch:4,iters:0, cost:0.83496475, accuracy:0.7
# Building top:  0.8
# tree top:  0.95
# big building:  0.45
# contrast:  0.6
# epoch:4,iters:10, cost:0.55522645, accuracy:0.525
# Building top:  0.85
# tree top:  0.2
# big building:  1.0
# contrast:  0.05
# epoch:4,iters:20, cost:0.50684756, accuracy:0.75
# Building top:  0.9
# tree top:  1.0
# big building:  0.15
# contrast:  0.95
# epoch:4,iters:30, cost:0.5952248, accuracy:0.8375
# Building top:  0.8
# tree top:  1.0
# big building:  0.55
# contrast:  1.0
# epoch:5,iters:0, cost:0.6347645, accuracy:0.8
# Building top:  0.8
# tree top:  1.0
# big building:  0.55
# contrast:  0.85
# epoch:5,iters:10, cost:0.55328655, accuracy:0.5875
# Building top:  0.85
# tree top:  0.3
# big building:  1.0
# contrast:  0.2
# epoch:5,iters:20, cost:0.5598712, accuracy:0.825
# Building top:  0.9
# tree top:  1.0
# big building:  0.4
# contrast:  1.0
# epoch:5,iters:30, cost:0.42933017, accuracy:0.8875
# Building top:  0.85
# tree top:  1.0
# big building:  0.7
# contrast:  1.0
# epoch:6,iters:0, cost:0.4227417, accuracy:0.8625
# Building top:  0.85
# tree top:  1.0
# big building:  0.6
# contrast:  1.0
# epoch:6,iters:10, cost:0.36396945, accuracy:0.75
# Building top:  0.95
# tree top:  0.7
# big building:  1.0
# contrast:  0.35
# epoch:6,iters:20, cost:0.35846615, accuracy:0.8375
# Building top:  0.9
# tree top:  1.0
# big building:  0.45
# contrast:  1.0
# epoch:6,iters:30, cost:0.3193304, accuracy:0.9
# Building top:  0.95
# tree top:  1.0
# big building:  0.65
# contrast:  1.0
# epoch:7,iters:0, cost:0.39704615, accuracy:0.85
# Building top:  0.85
# tree top:  1.0
# big building:  0.55
# contrast:  1.0
# epoch:7,iters:10, cost:0.331366, accuracy:0.8375
# Building top:  0.95
# tree top:  0.9
# big building:  1.0
# contrast:  0.5
# epoch:7,iters:20, cost:0.34507376, accuracy:0.8875
# Building top:  0.95
# tree top:  1.0
# big building:  0.6
# contrast:  1.0
# epoch:7,iters:30, cost:0.28074253, accuracy:0.925
# Building top:  0.95
# tree top:  1.0
# big building:  0.75
# contrast:  1.0
# epoch:8,iters:0, cost:0.39223367, accuracy:0.875
# Building top:  0.9
# tree top:  1.0
# big building:  0.6
# contrast:  1.0
# epoch:8,iters:10, cost:0.27236536, accuracy:0.8125
# Building top:  0.95
# tree top:  0.95
# big building:  0.95
# contrast:  0.4
# epoch:8,iters:20, cost:0.33272326, accuracy:0.9125
# Building top:  0.95
# tree top:  1.0
# big building:  0.7
# contrast:  1.0
# epoch:8,iters:30, cost:0.37208956, accuracy:0.9125
# Building top:  0.95
# tree top:  1.0
# big building:  0.7
# contrast:  1.0
# epoch:9,iters:0, cost:0.36056858, accuracy:0.8875
# Building top:  0.9
# tree top:  1.0
# big building:  0.65
# contrast:  1.0
# epoch:9,iters:10, cost:0.2511827, accuracy:0.85
# Building top:  0.95
# tree top:  0.95
# big building:  0.95
# contrast:  0.55
# epoch:9,iters:20, cost:0.36037832, accuracy:0.8
# Building top:  0.95
# tree top:  1.0
# big building:  0.45
# contrast:  0.8
# epoch:9,iters:30, cost:0.37033156, accuracy:0.825
# Building top:  0.85
# tree top:  1.0
# big building:  0.5
# contrast:  0.95
# epoch:10,iters:0, cost:0.6311528, accuracy:0.8125
# Building top:  0.9
# tree top:  1.0
# big building:  0.6
# contrast:  0.75
# epoch:10,iters:10, cost:0.3520612, accuracy:0.525
# Building top:  0.85
# tree top:  0.3
# big building:  0.95
# contrast:  0.0
# epoch:10,iters:20, cost:0.32665515, accuracy:0.85
# Building top:  0.9
# tree top:  1.0
# big building:  0.6
# contrast:  0.9
# epoch:10,iters:30, cost:0.37454742, accuracy:0.875
# Building top:  0.95
# tree top:  1.0
# big building:  0.55
# contrast:  1.0
# epoch:11,iters:0, cost:0.569878, accuracy:0.9
# Building top:  1.0
# tree top:  1.0
# big building:  0.6
# contrast:  1.0
# epoch:11,iters:10, cost:0.36333287, accuracy:0.6125
# Building top:  0.9
# tree top:  0.45
# big building:  0.95
# contrast:  0.15
# epoch:11,iters:20, cost:0.43931943, accuracy:0.875
# Building top:  1.0
# tree top:  1.0
# big building:  0.55
# contrast:  0.95
# epoch:11,iters:30, cost:0.3097709, accuracy:0.9
# Building top:  0.95
# tree top:  1.0
# big building:  0.65
# contrast:  1.0
# epoch:12,iters:0, cost:0.5223932, accuracy:0.8875
# Building top:  0.95
# tree top:  1.0
# big building:  0.6
# contrast:  1.0
# epoch:12,iters:10, cost:0.34585324, accuracy:0.6125
# Building top:  0.9
# tree top:  0.45
# big building:  0.95
# contrast:  0.15
# epoch:12,iters:20, cost:0.4046401, accuracy:0.9
# Building top:  1.0
# tree top:  1.0
# big building:  0.6
# contrast:  1.0
# epoch:12,iters:30, cost:0.31040412, accuracy:0.9
# Building top:  0.95
# tree top:  1.0
# big building:  0.65
# contrast:  1.0
# epoch:13,iters:0, cost:0.43042436, accuracy:0.7875
# Building top:  1.0
# tree top:  1.0
# big building:  0.3
# contrast:  0.85
# epoch:13,iters:10, cost:0.3836991, accuracy:0.6125
# Building top:  0.95
# tree top:  0.35
# big building:  0.85
# contrast:  0.3
# epoch:13,iters:20, cost:0.45274115, accuracy:0.8625
# Building top:  0.95
# tree top:  1.0
# big building:  0.55
# contrast:  0.95
# epoch:13,iters:30, cost:0.27528715, accuracy:0.875
# Building top:  0.9
# tree top:  0.9
# big building:  0.7
# contrast:  1.0
# epoch:14,iters:0, cost:0.42339295, accuracy:0.8
# Building top:  0.95
# tree top:  1.0
# big building:  0.45
# contrast:  0.8
# epoch:14,iters:10, cost:0.38737872, accuracy:0.7125
# Building top:  0.95
# tree top:  0.6
# big building:  0.85
# contrast:  0.45
# epoch:14,iters:20, cost:0.37080964, accuracy:0.8875
# Building top:  1.0
# tree top:  0.95
# big building:  0.6
# contrast:  1.0
# epoch:14,iters:30, cost:0.32333782, accuracy:0.875
# Building top:  0.9
# tree top:  1.0
# big building:  0.65
# contrast:  0.95
# epoch:15,iters:0, cost:0.27532935, accuracy:0.8
# Building top:  0.95
# tree top:  1.0
# big building:  0.5
# contrast:  0.75
# epoch:15,iters:10, cost:0.4228994, accuracy:0.6875
# Building top:  0.9
# tree top:  0.6
# big building:  0.95
# contrast:  0.3
# epoch:15,iters:20, cost:0.26228958, accuracy:0.8375
# Building top:  0.95
# tree top:  1.0
# big building:  0.45
# contrast:  0.95
# epoch:15,iters:30, cost:0.2818772, accuracy:0.8875
# Building top:  0.9
# tree top:  1.0
# big building:  0.7
# contrast:  0.95
# epoch:16,iters:0, cost:0.22343385, accuracy:0.8
# Building top:  0.95
# tree top:  1.0
# big building:  0.5
# contrast:  0.75
# epoch:16,iters:10, cost:0.50999653, accuracy:0.725
# Building top:  0.95
# tree top:  0.65
# big building:  0.95
# contrast:  0.35
# epoch:16,iters:20, cost:0.16889337, accuracy:0.8625
# Building top:  0.95
# tree top:  1.0
# big building:  0.55
# contrast:  0.95
# epoch:16,iters:30, cost:0.267209, accuracy:0.8875
# Building top:  0.95
# tree top:  0.95
# big building:  0.7
# contrast:  0.95
# epoch:17,iters:0, cost:0.22269726, accuracy:0.8625
# Building top:  0.95
# tree top:  1.0
# big building:  0.6
# contrast:  0.9
# epoch:17,iters:10, cost:0.3439856, accuracy:0.725
# Building top:  0.95
# tree top:  0.55
# big building:  1.0
# contrast:  0.4
# epoch:17,iters:20, cost:0.2944994, accuracy:0.8875
# Building top:  0.95
# tree top:  1.0
# big building:  0.6
# contrast:  1.0
# epoch:17,iters:30, cost:0.19339065, accuracy:0.9125
# Building top:  0.95
# tree top:  0.9
# big building:  0.85
# contrast:  0.95
# epoch:18,iters:0, cost:0.23315656, accuracy:0.8875
# Building top:  0.95
# tree top:  1.0
# big building:  0.75
# contrast:  0.85
# epoch:18,iters:10, cost:0.33987468, accuracy:0.75
# Building top:  0.9
# tree top:  0.7
# big building:  1.0
# contrast:  0.4
# epoch:18,iters:20, cost:0.33671218, accuracy:0.8875
# Building top:  0.95
# tree top:  1.0
# big building:  0.6
# contrast:  1.0
# epoch:18,iters:30, cost:0.17124943, accuracy:0.9
# Building top:  0.95
# tree top:  0.9
# big building:  0.8
# contrast:  0.95
# epoch:19,iters:0, cost:0.20913725, accuracy:0.8875
# Building top:  0.95
# tree top:  1.0
# big building:  0.65
# contrast:  0.95
# epoch:19,iters:10, cost:0.40441352, accuracy:0.8
# Building top:  0.95
# tree top:  0.8
# big building:  0.95
# contrast:  0.5
# epoch:19,iters:20, cost:0.25471672, accuracy:0.8375
# Building top:  0.95
# tree top:  1.0
# big building:  0.5
# contrast:  0.9
# epoch:19,iters:30, cost:0.16438076, accuracy:0.9375
# Building top:  0.95
# tree top:  1.0
# big building:  0.85
# contrast:  0.95

# %%
"""
tensorboard, need be fixed
"""

# with tf.name_scope('conv1'):
#         conv1 = tf.nn.conv2d(x4d, weight_variable('conv1', [5, 5, 3, 64], 5e-2, 'w_conv1'), strides=[1, 1, 1, 1], padding='SAME')
#         conv1 = tf.nn.bias_add(conv1, bias_variable('conv1', 0.0, tf.float32, [64], 'b_conv1'))
#         conv1 = tf.nn.relu(conv1)

# with tf.name_scope('accuracy'):
#         with tf.name_scope('correct_prediction'):
#             correct_pred = tf.equal(tf.argmax(fc3, 1), tf.argmax(y, 1))
#         with tf.name_scope('accuracy'):
#             accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
#     tf.summary.scalar('accuracy', accuracy)

# merged_summary_op = tf.summary.merge_all()

# summary_writer = tf.summary.FileWriter('./tensorboard/log/', graph=tf.get_default_graph())

# %%
"""
save model if when completed
"""
# v1 = tf.Variable(tf.constant(1.0, shape=[1]), name="v1")
# v2 = tf.Variable(tf.constant(2.0, shape=[1]), name="v2")
# result = v1 + v2

# init_op = tf.global_variables_initializer()
# # declare:train.Saver  used to save model
# saver = tf.train.Saver()

# with tf.Session() as sess:
#     sess.run(init_op)
#     #save as : /tensorflow_google/model/model.ckpt
#     saver.save(sess, "/model/model.ckpt")
